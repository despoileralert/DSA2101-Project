# %% [markdown]
# # DSA2101 Project: Global Holidays and travel.
# In this project, we want to identify

# %% [markdown]
# As usual, we import all the packages and read the data in.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

global_holidays = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2024/2024-12-24/global_holidays.csv')
monthly_passengers = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2024/2024-12-24/monthly_passengers.csv')

# %%
global_holidays.head()
global_holidays['Date'] = pd.to_datetime(global_holidays['Date'])
global_holidays['Year'] = global_holidays['Date'].dt.year
global_holidays['Month'] = global_holidays['Date'].dt.month

global_holidays
# Out:
#         ADM_name ISO3       Date                          Name  \
# 0          Aruba  ABW 2010-01-01                New Year's Day
# 1          Aruba  ABW 2010-01-25        Betico Croes' Birthday
# 2          Aruba  ABW 2010-02-15               Carnival Monday
# 3          Aruba  ABW 2010-03-18  National Anthem and Flag Day
# 4          Aruba  ABW 2010-04-02                   Good Friday
# ...          ...  ...        ...                           ...
# 44388  Palestine  PSE 2015-12-24            Prophet's Birthday
# 44389  Palestine  PSE 2016-12-12            Prophet's Birthday
# 44390  Palestine  PSE 2017-12-01            Prophet's Birthday
# 44391  Palestine  PSE 2018-11-21            Prophet's Birthday
# 44392  Palestine  PSE 2019-11-10            Prophet's Birthday
#
#                  Type  Year  Month
# 0      Public holiday  2010      1
# 1      Public holiday  2010      1
# 2      Public holiday  2010      2
# 3      Public holiday  2010      3
# 4      Public holiday  2010      4
# ...               ...   ...    ...
# 44388  Public holiday  2015     12
# 44389  Public holiday  2016     12
# 44390  Public holiday  2017     12
# 44391  Public holiday  2018     11
# 44392  Public holiday  2019     11
#
# [44393 rows x 7 columns]

# %%
monthly_passengers.dropna(inplace = True)
global_holidays.dropna(inplace = True)
monthly_passengers.drop_duplicates(inplace = True)
global_holidays.drop_duplicates(inplace = True)

monthly_passengers
# Out:
#      ISO3  Year  Month    Total  Domestic  International    Total_OS
# 281   AUS  2014      1   7992.0    4790.0         3202.0   12600.040
# 282   AUS  2014      2   6697.0    4207.0         2490.0   10731.179
# 283   AUS  2014      3   7277.0    4745.0         2532.0   11823.253
# 284   AUS  2014      4   7467.0    4757.0         2710.0   12026.674
# 285   AUS  2014      5   6977.0    4529.0         2449.0   11312.633
# ...   ...   ...    ...      ...       ...            ...         ...
# 7177  USA  2017      8  77563.0   66856.0        10708.0  144966.412
# 7178  USA  2017      9  65316.0   57405.0         7913.0  123563.734
# 7179  USA  2017     10  73143.0   64908.0         8235.0  138308.935
# 7180  USA  2017     11  70018.0   62162.0         7856.0  131553.688
# 7181  USA  2017     12  70666.0   61577.0         9089.0  132184.624
#
# [2706 rows x 7 columns]

# %% [markdown]
# First we merge the two cleaned tables together, in order to get the holiday joined on country, year and month. The Name and Type columns that were joined from the global holidays help us to identify the holidays in question.

# %%
df_clean = monthly_passengers.merge(global_holidays, on = ['ISO3', 'Year', 'Month'], how = 'left')
df_clean.drop(columns = ['Date', 'Name'], inplace = True)
df_clean.head()
# Out:
#   ISO3  Year  Month   Total  Domestic  International   Total_OS   ADM_name  \
# 0  AUS  2014      1  7992.0    4790.0         3202.0  12600.040  Australia
# 1  AUS  2014      1  7992.0    4790.0         3202.0  12600.040  Australia
# 2  AUS  2014      1  7992.0    4790.0         3202.0  12600.040  Australia
# 3  AUS  2014      1  7992.0    4790.0         3202.0  12600.040  Australia
# 4  AUS  2014      2  6697.0    4207.0         2490.0  10731.179  Australia
#
#              Type
# 0      Observance
# 1  Public holiday
# 2  Public holiday
# 3  Public holiday
# 4      Observance

# %%
df_clean['Type'].value_counts()
# Out:
# Type
# Public holiday               2574
# Observance                   2276
# Local holiday                 659
# Local observance              269
# Special holiday                82
# Working day (replacement)      39
# Half-day holiday               12
# Name: count, dtype: int64

# %% [markdown]
# Below, we group by country, year and month to obtain the number of holidays each country has per year, in every month. Then, we merge back to the monthly passengers table on the ISO3, Year and Month columns to get back the data lost while grouping. This table provides us with holiday types as well as their counts for every country per year grouped by month, in addition to the passenger statistics. Value_counts() is used as the aggregator to further separating the type column to the types of holidays that are present.

# %%
df_clean_valcount = df_clean.groupby(['ISO3','Year','Month'])[['Type']].value_counts().reset_index()
df_clean_valcount = df_clean_valcount.merge(monthly_passengers, on = ['ISO3', 'Year', 'Month'], how = 'inner')
df_clean_valcount
# Out:
#      ISO3  Year  Month              Type  count    Total  Domestic  \
# 0     AUS  2014      1    Public holiday      3   7992.0    4790.0
# 1     AUS  2014      1        Observance      1   7992.0    4790.0
# 2     AUS  2014      2        Observance      1   6697.0    4207.0
# 3     AUS  2014      3        Observance      3   7277.0    4745.0
# 4     AUS  2014      3    Public holiday      1   7277.0    4745.0
# ...   ...   ...    ...               ...    ...      ...       ...
# 3063  USA  2017     11        Observance      3  70018.0   62162.0
# 3064  USA  2017     11    Public holiday      3  70018.0   62162.0
# 3065  USA  2017     12        Observance      8  70666.0   61577.0
# 3066  USA  2017     12  Local observance      1  70666.0   61577.0
# 3067  USA  2017     12    Public holiday      1  70666.0   61577.0
#
#       International    Total_OS
# 0            3202.0   12600.040
# 1            3202.0   12600.040
# 2            2490.0   10731.179
# 3            2532.0   11823.253
# 4            2532.0   11823.253
# ...             ...         ...
# 3063         7856.0  131553.688
# 3064         7856.0  131553.688
# 3065         9089.0  132184.624
# 3066         9089.0  132184.624
# 3067         9089.0  132184.624
#
# [3068 rows x 9 columns]

# %% [markdown]
# Added a date column in the dataframe so that we can more easily plot Total_OS by time.

# %%
df_clean_count = df_clean.groupby(['ISO3','Year','Month'])[['Type']].count().reset_index()
df_clean_count = df_clean_count.merge(monthly_passengers, on = ['ISO3', 'Year', 'Month'], how = 'inner')
df_clean_count.rename(columns = {'Type': 'HolidayCount'}, inplace = True)
df_clean_count['Date'] = pd.to_datetime(df_clean_count['Year'].astype(str) + 
                                        df_clean_count['Month'].astype(str), format='%Y%m') #https://www.marsja.se/combine-year-and-month-columns-in-pandas/
df_clean_count
# Out:
#      ISO3  Year  Month  HolidayCount    Total  Domestic  International  \
# 0     AUS  2014      1             4   7992.0    4790.0         3202.0
# 1     AUS  2014      2             1   6697.0    4207.0         2490.0
# 2     AUS  2014      3             4   7277.0    4745.0         2532.0
# 3     AUS  2014      4             5   7467.0    4757.0         2710.0
# 4     AUS  2014      5             2   6977.0    4529.0         2449.0
# ...   ...   ...    ...           ...      ...       ...            ...
# 2701  USA  2017      8             6  77563.0   66856.0        10708.0
# 2702  USA  2017      9            13  65316.0   57405.0         7913.0
# 2703  USA  2017     10            11  73143.0   64908.0         8235.0
# 2704  USA  2017     11             6  70018.0   62162.0         7856.0
# 2705  USA  2017     12            10  70666.0   61577.0         9089.0
#
#         Total_OS       Date
# 0      12600.040 2014-01-01
# 1      10731.179 2014-02-01
# 2      11823.253 2014-03-01
# 3      12026.674 2014-04-01
# 4      11312.633 2014-05-01
# ...          ...        ...
# 2701  144966.412 2017-08-01
# 2702  123563.734 2017-09-01
# 2703  138308.935 2017-10-01
# 2704  131553.688 2017-11-01
# 2705  132184.624 2017-12-01
#
# [2706 rows x 9 columns]

# %% [markdown]
# Converting from long to wide to aid plotting later on. df_clean_count is still the one to refer to should we wish to make other visualizations.

# %%
df_clean_count1 = df_clean_count.pivot(index = 'Date', columns = 'ISO3', values = 'Total')
df_clean_count1
# Out:
# ISO3           AUS       AUT       BEL       BGR       CHE      CHN       CYP  \
# Date
# 2010-01-01     NaN  1616.764  1337.584   273.780  2785.005      NaN       NaN
# 2010-02-01     NaN  1594.077  1397.881   242.626  2715.644      NaN   258.954
# 2010-03-01     NaN  1908.254  1678.130   273.116  3201.375      NaN       NaN
# 2010-04-01     NaN  1624.357  1544.861   245.311  2606.965      NaN   462.592
# 2010-05-01     NaN  2080.848  2078.077   424.416  3118.248      NaN   672.133
# ...            ...       ...       ...       ...       ...      ...       ...
# 2017-08-01  8197.0  2807.833  3408.657  1882.109  5247.904  50465.0       NaN
# 2017-09-01  8367.0  2734.285  3202.473  1304.988  4874.610  46547.0       NaN
# 2017-10-01  8754.0  2424.628  2982.388   670.632  4875.555  48831.0  1129.451
# 2017-11-01  8373.0  1947.157  2422.231   507.080  3596.127  46455.0       NaN
# 2017-12-01  9037.0  2050.629  2306.321   539.133  4015.045  46656.0       NaN
#
# ISO3             CZE        DEU       DNK  ...       NLD       NOR       POL  \
# Date                                       ...
# 2010-01-01   714.916  10206.993  1537.054  ...  3116.393  1935.960  1102.669
# 2010-02-01   685.925   9985.787  1609.501  ...  3051.339  2028.942  1080.644
# 2010-03-01   887.087  13090.984  1979.184  ...  3700.319  2398.396  1303.859
# 2010-04-01   816.449  10879.022  1466.776  ...  3215.276  1734.707  1139.301
# 2010-05-01  1050.300  15144.847  2156.579  ...  4449.154  2583.839  1643.950
# ...              ...        ...       ...  ...       ...       ...       ...
# 2017-08-01  1863.455  21571.733  3191.707  ...  7611.207  3675.007  4090.307
# 2017-09-01  1732.354  21252.374  3092.281  ...  7047.173  3535.065  3848.917
# 2017-10-01  1419.400  20230.108  3030.083  ...  6978.713  3507.313  3309.933
# 2017-11-01  1163.466  14971.010  2357.263  ...  5660.201  2943.422  2754.558
# 2017-12-01  1185.885  14061.288  2209.374  ...  5440.063  2665.340  2740.903
#
# ISO3             PRT       ROU      SVK  SVN       SWE        THA      USA
# Date
# 2010-01-01  1472.232   590.930  100.151  NaN  1750.487        NaN  53043.0
# 2010-02-01  1433.205   528.116   98.600  NaN  1805.106        NaN  49091.0
# 2010-03-01  1772.630   657.611  118.586  NaN  2213.762        NaN  62735.0
# 2010-04-01  1917.346   647.471   99.046  NaN  1611.699        NaN  60145.0
# 2010-05-01  2250.234   731.926  135.270  NaN  2424.184        NaN  61941.0
# ...              ...       ...      ...  ...       ...        ...      ...
# 2017-08-01  5257.066  1888.352  375.234  NaN  3637.417  11400.918  77563.0
# 2017-09-01  4880.541  1756.433  269.858  NaN  3557.400   9844.193  65316.0
# 2017-10-01  4473.343  1620.942  176.187  NaN  3423.537   9676.856  73143.0
# 2017-11-01  3151.693  1309.112  146.118  NaN  2929.925   9768.942  70018.0
# 2017-12-01  3146.631  1298.264  147.892  NaN  2732.795  11273.828  70666.0
#
# [96 rows x 35 columns]
